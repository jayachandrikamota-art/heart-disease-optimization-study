# %% [markdown]
# #“A Comprehensive Comparative Study of Modern Optimization Algorithms on Heart Disease Prediction”

# %% [markdown]
# #Performing Preprocessing and EDA on dataset

# %%
import pandas as pd
df = pd.read_csv("/content/heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# Scaling some features

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df["trestbps"] = scaler.fit_transform(df[["trestbps"]])
df["chol"] = scaler.fit_transform(df[["chol"]])
df["thalach"] = scaler.fit_transform(df[["thalach"]])
df.head()
# Out:
#    age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  oldpeak  \
# 0   63    1   3  0.481132  0.244292    1        0  0.603053      0      2.3
# 1   37    1   2  0.339623  0.283105    0        1  0.885496      0      3.5
# 2   41    0   1  0.339623  0.178082    0        0  0.770992      0      1.4
# 3   56    1   1  0.245283  0.251142    0        1  0.816794      0      0.8
# 4   57    0   0  0.245283  0.520548    0        1  0.702290      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.show()

# %%
sns.boxplot(df['chol'])
plt.show()

# %%
sns.boxplot(df["thalach"])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='target', palette='coolwarm')
plt.title('Target Variable Distribution (0 = No Disease, 1 = Disease)')
plt.xlabel("Heart Disease Presence")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipython-input-3244738400.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='target', palette='coolwarm')

# %%
# Skewness
print(df.skew())

# Outlier detection (Z-score)
from scipy import stats
z = np.abs(stats.zscore(df))
print("Number of outliers:", (z > 3).sum().sum())
# Out:
# age        -0.202463
# sex        -0.791335
# cp          0.484732
# trestbps    0.713768
# chol        1.143401
# fbs         1.986652
# restecg     0.162522
# thalach    -0.537410
# exang       0.742532
# oldpeak     1.269720
# slope      -0.508316
# ca          1.310422
# thal       -0.476722
# target     -0.179821
# dtype: float64
# Number of outliers: 16

# %%
from google.colab import files

df.to_csv('heart_cleaned.csv', index=False)
files.download('heart_cleaned.csv')

# %% [markdown]
# For applying Algortihms, we used preprocessed dataset.
